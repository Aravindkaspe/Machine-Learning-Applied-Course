# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
sepal_features = ['sepal length (cm)', 'sepal width (cm)']
petal_features = ['petal length (cm)', 'petal width (cm)']

# %%
sepal_lengths = data[sepal_features[0]].mean(), data[petal_features[0]].mean()
labels = ['Sepal Length', 'Petal Length']

plt.figure(figsize=(8, 8))
plt.pie(sepal_lengths, labels=labels, autopct=lambda p: '{:.2f}%\n({:.2f})'.format(p, p * sum(sepal_lengths)/100), startangle=90)
plt.title('Average Sepal Lengths')
plt.show()

# %%
data[sepal_features[0]].mean()
# Out:
# 5.843333333333334

# %%
plt.figure(figsize=(10, 6))
plt.hist(data[sepal_features[0]], bins=50, label='Sepal Length')
plt.title('Distribution of Sepal Lengths')
plt.xlabel('Length (cm)')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data[petal_features[0]])
plt.title('Line Chart for Petal Lengths')
plt.xlabel('Index')
plt.ylabel('Length (cm)')
plt.show()
